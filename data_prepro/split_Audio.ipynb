# %%
#split mp3

from pydub import AudioSegment
from pydub.utils import mediainfo
AudioSegment.converter = "d:\\ffmpeg\\bin\\ffmpeg"
filename='ip4_116'
mp3filename_path="F:/persian speech data/Data/wavs/"+filename+".wav"
sound = AudioSegment.from_wav(mp3filename_path)

sound.export("F:\\"+filename+"_"+str(1)+".wav", format="wav",bitrate=352836,)
# Out:
# <_io.BufferedRandom name='F:\\ip4_116_1.wav'>

# %%
count=1
with open("C:/Users/Home/Desktop/1111.txt", "r",encoding="utf-8") as f:
    for line in f.readlines():
        start=float(line.split(" ")[2])*1000
        end=float(line.split(" ")[3])*1000
        print(start,end)
        silence_chunk = AudioSegment.silent(duration=250)
        data =silence_chunk+ sound[start:end]+silence_chunk
        data.export("F:\\persian speech data\\NEW DATA WOMAN\\pas az to\\Data\\"+filename+"_"+str(count)+".wav", format="wav",)
        count=count+1
        print(count)
# Out:
# 0.0 13280.0
# 2
# 13280.0 26120.0
# 3
# 26120.0 33200.0
# 4
# 33200.0 49960.0
# 5
# 49960.0 67080.0
# 6
# 67080.0 70440.0
# 7
# 70440.0 72720.0
# 8
# 72720.0 77160.0
# 9
# 77160.0 85080.0
# 10
# 85080.0 104040.0
# 11
# 104040.0 114680.0
# 12
# 114680.0 116960.0
# 13
# 116960.0 126240.0
# 14
# 126240.0 141080.0
# 15
# 141080.0 147920.0
# 16
# 147920.0 153480.0
# 17
# 153480.0 157800.0
# 18
# 157800.0 163120.0
# 19
# 163120.0 172880.0
# 20
# 172880.0 178640.0
# 21
# 178640.0 201480.0
# 22
# 201480.0 207800.0
# 23
# 207800.0 208440.0
# 24
# 208440.0 211080.0
# 25
# 211080.0 214400.0
# 26
# 214400.0 217960.0
# 27
# 217960.0 223040.0
# 28
# 223040.0 237360.0
# 29
# 237360.0 244960.0
# 30
# 244960.0 265240.0
# 31
# 265240.0 274240.0
# 32
# 274240.0 278360.0
# 33
# 278360.0 287440.0
# 34
# 287440.0 291440.0
# 35
# 291440.0 298880.0
# 36
# 298880.0 319080.0
# 37
# 319080.0 324880.0
# 38
# 324880.0 329160.0
# 39
# 329160.0 334760.0
# 40
# 334760.0 341760.0
# 41
# 341760.0 344680.0
# 42
# ...

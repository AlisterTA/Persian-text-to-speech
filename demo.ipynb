# %%
import sys
import os
import numpy as np
import tensorflow as tf
sys.path.append('tools')
sys.path.append('network')
# %load_ext autoreload
# %autoreload 2

from hp import HP
from model_graph import model
tf.reset_default_graph()

# %%
gr=model('null','demo')
# Out:
# INFO:tensorflow:Restoring parameters from logs/text-to-spec\model_gs_140k
# INFO:tensorflow:Restoring parameters from logs/super_resolution\model_gs_141k
# model loaded :)

# %% [markdown]
# # Enter Your Text

# %%
sentenses=["معلوم بود واقعا به دنبال جوابى براى سوالش نیست"]

# %%
gr.predict(sentenses)
# Out:
# ['معلوم بود واقعا به دنبال جوابى براى سوالش نیستE']
# predicting ( . •́ _ʖ •̀ .) ...
# 100%|████████████████████████████████████████| 209/209 [00:07<00:00, 29.66it/s]
# convert the generated spectrogram to audio ｖ(⌒ｏ⌒)ｖ♪ ...
# DONE!

# %%
import IPython
IPython.display.Audio("generated_samples/1.wav")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
